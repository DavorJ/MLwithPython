# %% [markdown]
# # Loading data

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# In this exercise, we will explore insurance data. What we are mainly interested in, is what the charges look like.

# %% [markdown]
# Read data from https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv and store it as a dataframe in variable _sample_.

# %%
sample =

# %% [markdown]
# Show the first lines of the data frame.

# %%
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Exploring the data

# %% [markdown]
# ## Summary statistics

# %% [markdown]
# Show a summary of the "charges".

# %%
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %% [markdown]
# How much is the sample variance of "charges"?

# %%
# Out:
# 146652372.15285498

# %% [markdown]
# What is the standard deviation?

# %%
# Out:
# 12110.011236694001

# %% [markdown]
# What is the Pearson correlation coefficient between charges and BMI?

# %%
# Out:
#           charges       bmi
# charges  1.000000  0.198341
# bmi      0.198341  1.000000

# %% [markdown]
# How many records are there per region?

# %%
# Out:
# region
# northeast    324
# northwest    325
# southeast    364
# southwest    325
# Name: region, dtype: int64

# %% [markdown]
# ## Boxplot

# %% [markdown]
# Show a boxplot of the charges.

# %% [markdown]
# ## Histogram

# %% [markdown]
# Create a histogram of the charges.

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# How does BMI relate to charges?

# %% [markdown]
# Can you show age, bmi and charges in one plot?
